# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pandas-with-indonesia-belajar/blob/main/Pandas_55_Menghitung_jumlah_baris_menurut_kriteria_tertentu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas 55: Menghitung jumlah baris menurut kriteria tertentu | Python Pandas | Belajar Data Science**

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %% [markdown]
# Persiapan DataFrame

# %%
n_rows = 10
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)),
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  6  1  5  5  5
# 1  2  9  8  9  7
# 2  5  7  8  9  1
# 3  1  4  7  3  2
# 4  5  6  1  7  2
# 5  3  9  1  5  6
# 6  4  5  5  3  3
# 7  2  3  8  8  6
# 8  2  9  9  7  8
# 9  9  8  1  3  8

# %% [markdown]
# Menghitung jumlah baris menurut kriteria tertentu

# %%
(df['A'] < 5).sum()
# Out:
# 6

# %%
(df['A'] < 5).mean()  # Proporsi rata-rata
# Out:
# 0.6
