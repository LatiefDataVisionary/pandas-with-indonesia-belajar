# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pandas-with-indonesia-belajar/blob/main/Pandas_01___Menyertakan_Prefix_dan_Suffix_pada_seluruh_Kolom_Pandas_Data_Frame___Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')
df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  3  2  6  4  7
# 1  4  5  5  1  2
# 2  6  2  8  5  2
# 3  1  3  4  7  9
# 4  8  8  9  7  9

# %%
tuple('ABCDE')
# Out:
# ('A', 'B', 'C', 'D', 'E')

# %% [markdown]
# Menyertakan Prefix Kolom (Sekumpulan string di bagian depan nama kolom)

# %%
df.add_prefix('kolom_')
# Out:
#    kolom_A  kolom_B  kolom_C  kolom_D  kolom_E
# 0        3        2        6        4        7
# 1        4        5        5        1        2
# 2        6        2        8        5        2
# 3        1        3        4        7        9
# 4        8        8        9        7        9

# %% [markdown]
# Menyertakan Suffix Kolom (Sekumpulan string di bagian belakang nama kolom)

# %%
df.add_suffix('_field')
# Out:
#    A_field  B_field  C_field  D_field  E_field
# 0        3        2        6        4        7
# 1        4        5        5        1        2
# 2        6        2        8        5        2
# 3        1        3        4        7        9
# 4        8        8        9        7        9
