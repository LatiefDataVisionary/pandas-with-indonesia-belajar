# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pandas-with-indonesia-belajar/blob/main/Pandas_36_Menyatukan_kolom_pada_Pandas_Data_Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas 36: Menyatukan kolom pada Pandas Data Frame _ Python Pandas _ Belajar Data Science**

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %% [markdown]
# Persiapan DataFrame

# %%
data = {'nama': ['bayu', 'indra', 'devi', 'agni'],
        'jenis_kelamin': ['L', 'L', 'P', 'L'],
        'usia': [23,21,22,25]}

df = pd.DataFrame(data)
df
# Out:
#     nama jenis_kelamin  usia
# 0   bayu             L    23
# 1  indra             L    21
# 2   devi             P    22
# 3   agni             L    25

# %% [markdown]
# Menyatukan kolom dengan `str.cat()`

# %%
df['nama'].str.cat(df['jenis_kelamin'], sep=', ').to_frame()
# Out:
#        nama
# 0   bayu, L
# 1  indra, L
# 2   devi, P
# 3   agni, L

# %%
df['nama_jk'] = df['nama'].str.cat(df['jenis_kelamin'], sep=', ')
df
# Out:
#     nama jenis_kelamin  usia   nama_jk
# 0   bayu             L    23   bayu, L
# 1  indra             L    21  indra, L
# 2   devi             P    22   devi, P
# 3   agni             L    25   agni, L

# %%
df['nama'].str.cat(df['usia'].astype('str'), sep=' - ').to_frame()
# Out:
#          nama
# 0   bayu - 23
# 1  indra - 21
# 2   devi - 22
# 3   agni - 25

# %%
df['nama_usia'] = df['nama'].str.cat(df['usia'].astype('str'), sep=' - ').to_frame()
df
# Out:
#     nama jenis_kelamin  usia   nama_jk   nama_usia
# 0   bayu             L    23   bayu, L   bayu - 23
# 1  indra             L    21  indra, L  indra - 21
# 2   devi             P    22   devi, P   devi - 22
# 3   agni             L    25   agni, L   agni - 25
