# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pandas-with-indonesia-belajar/blob/main/Pandas_51_Seleksi_Baris_dengan_between.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas 51: Seleksi Baris dengan `between()` | Python Pandas | Data Frame | Belajar Data Science**

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %% [markdown]
# Persiapan DataFrame

# %%
n_rows = 10
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)),
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  9  8  7  2  2
# 1  6  1  1  3  8
# 2  4  2  5  8  7
# 3  4  9  8  7  6
# 4  7  7  2  7  3
# 5  9  1  7  4  5
# 6  3  5  1  4  9
# 7  2  9  7  5  3
# 8  3  4  8  3  2
# 9  5  6  3  9  8

# %% [markdown]
# Seleksi baris dengan `between()`

# %%
df[df['A'].between(2,5)]
# Out:
#    A  B  C  D  E
# 2  4  2  5  8  7
# 3  4  9  8  7  6
# 6  3  5  1  4  9
# 7  2  9  7  5  3
# 8  3  4  8  3  2
# 9  5  6  3  9  8

# %%
df[df['A'].between(2,5, inclusive='neither')]
# Out:
#    A  B  C  D  E
# 2  4  2  5  8  7
# 3  4  9  8  7  6
# 6  3  5  1  4  9
# 8  3  4  8  3  2
