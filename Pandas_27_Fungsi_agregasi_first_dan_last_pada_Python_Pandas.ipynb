# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pandas-with-indonesia-belajar/blob/main/Pandas_27_Fungsi_agregasi_first_dan_last_pada_Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas 27: Fungsi agregasi `first() ` dan `last()` pada Python Pandas _ Data Science _ Bahasa Indonesia**

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %% [markdown]
# Persiapan DataFrame

# %%
d = {'dokter':['Budi', 'Wati', 'Iwan', 'Budi', 'Budi', 'Wati'],
     'pasien':['Abdul', 'Rahmat', 'Asep', 'Joko', 'Wiwin', 'Lisa']}

df = pd.DataFrame(d)
df
# Out:
#   dokter  pasien
# 0   Budi   Abdul
# 1   Wati  Rahmat
# 2   Iwan    Asep
# 3   Budi    Joko
# 4   Budi   Wiwin
# 5   Wati    Lisa

# %% [markdown]
# Mengenal fungsi agregasi `first()` dan `last()`

# %%
df.groupby('dokter')['pasien'].count().to_frame()
# Out:
#         pasien
# dokter
# Budi         3
# Iwan         1
# Wati         2

# %%
df.groupby('dokter')['pasien'].first().to_frame()
# Out:
#         pasien
# dokter
# Budi     Abdul
# Iwan      Asep
# Wati    Rahmat

# %%
df.groupby('dokter')['pasien'].last().to_frame()
# Out:
#        pasien
# dokter
# Budi    Wiwin
# Iwan     Asep
# Wati     Lisa
