# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pandas-with-indonesia-belajar/blob/main/Pandas_28_Mengenal_explode_dan_implode_List_pada_Pandas_Data_Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas 28: Mengenal explode dan implode List pada Pandas Data Frame _ Python Pandas _ Data Science**

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %% [markdown]
# Persiapan DataFrame

# %%
d = {'Team':['DC','Marvel'],
     'Heroes':[['Batman','Superman','Wonder Woman','Aquaman','Green Lantern','Shazam'],
               ['Iron Man','Captain America','Ant-Man','Black Panther','Captain Marvel']]}

df = pd.DataFrame(d)
df
# Out:
#      Team                                             Heroes
# 0      DC  [Batman, Superman, Wonder Woman, Aquaman, Gree...
# 1  Marvel  [Iron Man, Captain America, Ant-Man, Black Pan...

# %% [markdown]
# Explode

# %%
df1 = df.explode('Heroes')
df1
# Out:
#      Team           Heroes
# 0      DC           Batman
# 0      DC         Superman
# 0      DC     Wonder Woman
# 0      DC          Aquaman
# 0      DC    Green Lantern
# 0      DC           Shazam
# 1  Marvel         Iron Man
# 1  Marvel  Captain America
# 1  Marvel          Ant-Man
# 1  Marvel    Black Panther
# 1  Marvel   Captain Marvel

# %% [markdown]
# Implode

# %%
d = {'Team':['DC', 'Marvel']}
df2 = pd.DataFrame(d)
df2
# Out:
#      Team
# 0      DC
# 1  Marvel

# %%
df2['Imploded'] = df1.groupby(df1.index)['Heroes'].agg(list)
df2
# Out:
#      Team                                           Imploded
# 0      DC  [Batman, Superman, Wonder Woman, Aquaman, Gree...
# 1  Marvel  [Iron Man, Captain America, Ant-Man, Black Pan...
