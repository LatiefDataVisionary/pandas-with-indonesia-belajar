# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pandas-with-indonesia-belajar/blob/main/Pandas_44_Menata_ulang_kolom_Data_Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas 44: Menata ulang kolom Data Frame | Python Pandas | Data Science | Bahasa Indonesia**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Persiapan DataFrame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)),
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  1  6  8  6  1
# 1  5  5  4  1  9
# 2  7  9  7  4  5
# 3  5  2  2  8  3
# 4  3  4  3  2  3

# %% [markdown]
# Menata ulang penempatan kolom pada DataFrame

# %%
df[['D', 'C', 'A', 'E', 'B']]
# Out:
#    D  C  A  E  B
# 0  6  8  1  1  6
# 1  1  4  5  9  5
# 2  4  7  7  5  9
# 3  8  2  5  3  2
# 4  2  3  3  3  4

# %%
df
# Out:
#    A  B  C  D  E
# 0  1  6  8  6  1
# 1  5  5  4  1  9
# 2  7  9  7  4  5
# 3  5  2  2  8  3
# 4  3  4  3  2  3

# %%
df = df[['D', 'C', 'A', 'E', 'B']]
df
# Out:
#    D  C  A  E  B
# 0  6  8  1  1  6
# 1  1  4  5  9  5
# 2  4  7  7  5  9
# 3  8  2  5  3  2
# 4  2  3  3  3  4
