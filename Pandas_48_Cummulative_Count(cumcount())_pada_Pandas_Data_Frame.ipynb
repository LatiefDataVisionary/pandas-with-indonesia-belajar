# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pandas-with-indonesia-belajar/blob/main/Pandas_48_Cummulative_Count(cumcount())_pada_Pandas_Data_Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas 48: Cummulative Count(`cumcount()`) pada Pandas Data Frame | Python Pandas | Belajar Data Science**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Persiapan DataFrame

# %%
d = {'penjual': ['bejo', 'tejo', 'wati', 'bejo', 'cecep', 'tejo', 'wati', 'bejo'],
     'barang': ['monitor', 'monitor', 'keyboard', 'mouse', 'keyboard', 'monitor', 'laptop', 'monitor']}

df = pd.DataFrame(d)
df
# Out:
#   penjual    barang
# 0    bejo   monitor
# 1    tejo   monitor
# 2    wati  keyboard
# 3    bejo     mouse
# 4   cecep  keyboard
# 5    tejo   monitor
# 6    wati    laptop
# 7    bejo   monitor

# %% [markdown]
# Mengenal Cummulative Count dengan `cumcount()`

# %%
df['count_tiap_penjual'] = df.groupby('penjual').cumcount() + 1
df
# Out:
#   penjual    barang  count_tiap_penjual
# 0    bejo   monitor                   1
# 1    tejo   monitor                   1
# 2    wati  keyboard                   1
# 3    bejo     mouse                   2
# 4   cecep  keyboard                   1
# 5    tejo   monitor                   2
# 6    wati    laptop                   2
# 7    bejo   monitor                   3

# %%
df['count_tiap_barang'] = df.groupby('barang').cumcount() + 1
df
# Out:
#   penjual    barang  count_tiap_penjual  count_tiap_barang
# 0    bejo   monitor                   1                  1
# 1    tejo   monitor                   1                  2
# 2    wati  keyboard                   1                  1
# 3    bejo     mouse                   2                  1
# 4   cecep  keyboard                   1                  2
# 5    tejo   monitor                   2                  3
# 6    wati    laptop                   2                  1
# 7    bejo   monitor                   3                  4

# %%
df['count_pasangan_kolom'] = df.groupby(['penjual', 'barang']).cumcount() + 1
df
# Out:
#   penjual    barang  count_tiap_penjual  count_tiap_barang  \
# 0    bejo   monitor                   1                  1
# 1    tejo   monitor                   1                  2
# 2    wati  keyboard                   1                  1
# 3    bejo     mouse                   2                  1
# 4   cecep  keyboard                   1                  2
# 5    tejo   monitor                   2                  3
# 6    wati    laptop                   2                  1
# 7    bejo   monitor                   3                  4
#
#    count_pasangan_kolom
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# 5                     2
# 6                     1
# 7                     2
